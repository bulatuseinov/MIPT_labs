# %%
from IPython.display import Image

# %% [markdown]
# # Лаборатоная работа № 1.3
# ## Эффект Рамзауэра –– рассеяние медленных электонов на атомах
# #### Работу выполнили студенты 772 группы:
# - Усеинов Булат
# - Зубков Максим
# - Шевцов Владимир

# %% [markdown]
# ## Часть I.
# ### Экспериментальная установка

# %%
Image(data='1.png', width=500, height=500)
