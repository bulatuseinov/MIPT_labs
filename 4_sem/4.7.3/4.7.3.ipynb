# %% [markdown]
# # Лабораторная работа № 4.7.3
# # "Изучение поляризованного света"
# ## Выполнили:
# - Усеинов Булат 778 гр.
# - Самойленко Александр 778 гр.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy import interpolate
import math
from IPython.core.display import Image, display

# %% [markdown]
# $\textbf{Цель работы}$: ознакомление с методами получения и анализа поляризованного света.

# %% [markdown]
# $\textbf{В работе используются}$: оптическая скамья с осветителем; зеленый светофильтр; два поляроида; черное зеркало; полированная эбонитовая пластинка; стопа стеклянных пластинок; слюдяные пластинки разной толщины; пластинки в $\dfrac{1}{4}$ и $\dfrac{1}{2}$ длины волны; пластинка в одну длину волны для зеленого света (пластинка чувствительного оттенка).

# %% [markdown]
# ## Часть I. Определение разрешённых направлений поляроидов

# %%
display(Image('1.png', width=500, unconfined=True))

# %%
# Первый поляроид:
zapr1 = 33
razr1 = zapr1 + 90
print("Разрешенное направление P1 = %.1f" % razr1,"˚")
print("Запрещенное направление P1 = %.1f" % zapr1,"˚")
# Out:
# Разрешенное направление P1 = 123.0 ˚
# Запрещенное направление P1 = 33.0 ˚

# %%
# Второй поляроид:
zapr2 = 25
razr2 = zapr2 + 90
print("Разрешенное направление P2 = %.1f" % razr2,"˚")
print("Запрещенное направление P2 = %.1f" % zapr2,"˚")
# Out:
# Разрешенное направление P2 = 115.0 ˚
# Запрещенное направление P2 = 25.0 ˚

# %% [markdown]
# ## Часть II. Определение угла Брюстера для эбонита

# %%
alpha_0 = 302
alpha_1 = 303
d_alpha = 10
dn = np.tan(((360 - d_alpha) * np.pi) / 180)
n0 = np.tan(((360 - alpha_0) * np.pi) / 180)
n1 = np.tan(((360 - alpha_1) * np.pi) / 180)
ntabl = 1.58
print("Показатели преломления эбонита:")

print("Без фильтра n = %.2f +-" % n0, round(abs(dn),1))
print("С фильтром n = %.2f +-" % n1, round(abs(dn),1))
print("Табличное n = %.2f" % ntabl)
# Out:
# Показатели преломления эбонита:
# Без фильтра n = 1.60 +- 0.2
# С фильтром n = 1.54 +- 0.2
# Табличное n = 1.58

# %% [markdown]
# ## Часть III. Исследование стопы

# %%
display(Image('2.png', width=500, unconfined=True))

# %% [markdown]
# ### Опишем наблюдаемые явления:
# - Поляризация линейная, т.к. при поворачивании поляроида мы видим максимум и минимум интенсивности света.
# - Вектор $\overrightarrow{E}$ составляет с нулем беселя для поляроида-2   33˚

# %% [markdown]
# ## Часть IV. Определение главных плоскостей двоякопреломляющих пластин

# %%
display(Image('3.png', width=500, unconfined=True))

# %%
pl1 = 14
pl2 = 84
print("Главные направления пластинки 1 совпадают с поляризаторами при ß1 = %.1f" % pl1)
print("Главные направления пластинки 2 совпадают с поляризаторами при ß2 = %.1f" % pl2)
# Out:
# Главные направления пластинки 1 совпадают с поляризаторами при ß1 = 14.0
# Главные направления пластинки 2 совпадают с поляризаторами при ß2 = 84.0

# %% [markdown]
# ## Часть V. Выделение пластин λ/2 и λ/4

# %% [markdown]
# ### Опишем наблюдаемые явления:
# - Пластинка 1: поляризация круговая, не наблюдаются минимумы и максимумы интенсивности.
# - Пластинка 2: поляризация линейная.
#
# Та пластинка, что дает круговую поляризацию является пластинкой $\frac{\lambda}{4}$.
#
# Таким образом:
# - Пластинка 1 это пластинка $\frac{\lambda}{4}$
#
# - Пластинка 2 это пластинка $\frac{\lambda}{2}$
